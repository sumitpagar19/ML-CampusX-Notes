# %%
# !pip install dtreeviz

# %%
import graphviz.backend as be

# %%
from sklearn.datasets import *
from dtreeviz.trees import *
from IPython.display import Image,display_svg,SVG

# %%
clas = tree.DecisionTreeClassifier()
iris = load_iris()
X_train = iris.data
y_train = iris.target
clas.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import plot_tree
plot_tree(clas)
# Out:
# [Text(0.5, 0.9166666666666666, 'x[3] <= 0.8\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(0.4230769230769231, 0.75, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(0.46153846153846156, 0.8333333333333333, 'True  '),
#  Text(0.5769230769230769, 0.75, 'x[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(0.5384615384615384, 0.8333333333333333, '  False'),
#  Text(0.3076923076923077, 0.5833333333333334, 'x[2] <= 4.95\ngini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(0.15384615384615385, 0.4166666666666667, 'x[3] <= 1.65\ngini = 0.041\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(0.07692307692307693, 0.25, 'gini = 0.0\nsamples = 47\nvalue = [0, 47, 0]'),
#  Text(0.23076923076923078, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.46153846153846156, 0.4166666666666667, 'x[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.38461538461538464, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
# ...

# %% [markdown]
# **1. classification**

# %%
from dtreeviz import dtreeviz

viz = dtreeviz(clas,
               X_train,
               y_train,
               feature_names=iris.feature_names,
               class_names = ["setosa", "versicolor", "virginica"])
viz
# Out:
# C:\Users\sumit\AppData\Local\Temp\ipykernel_13152\361839802.py:3: DeprecationWarning: dtreeviz() function is deprecated starting from version 2.0.
#  For the same functionality, please use this code instead:
#  m = dtreeviz.model(...)
#  m.view()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 from dtreeviz import dtreeviz
# ----> 3 viz = dtreeviz(clas,
#       4                X_train,
#       5                y_train,
#       6                feature_names=iris.feature_names,
#       7                class_names = ["setosa", "versicolor", "virginica"])
#       8 viz
#
# ...

# %%
# Step 1: Import everything needed
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from dtreeviz import dtreeviz
import numpy as np

# Step 2: Load data
iris = load_iris()
X = iris.data
y = iris.target

# Step 3: Train model
clf = DecisionTreeClassifier(max_depth=3)
clf.fit(X, y)

# Step 4: Check types to be sure
print(type(y))          # should be <class 'numpy.ndarray'>
print(y.shape)          # should be (150,)
print(y[:5])            # should print first 5 labels

# Step 5: Create visualization
viz = dtreeviz(
    clf,
    X,
    y,
    target_name="species",
    feature_names=iris.feature_names,
    class_names=list(iris.target_names)  # make sure this is a list of strings
)

# Step 6: Display visualization (in Jupyter)
viz.show()  

# If you are NOT using Jupyter, then use:
# viz.view()
# Out:
# <class 'numpy.ndarray'>
# (150,)
# [0 0 0 0 0]
# C:\Users\sumit\AppData\Local\Temp\ipykernel_13152\1015219486.py:22: DeprecationWarning: dtreeviz() function is deprecated starting from version 2.0.
#  For the same functionality, please use this code instead:
#  m = dtreeviz.model(...)
#  m.view()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 22
#      19 print(y[:5])            # should print first 5 labels
#      21 # Step 5: Create visualization
# ---> 22 viz = dtreeviz(
#      23     clf,
#      24     X,
#      25     y,
#      26     target_name="species",
#      27     feature_names=iris.feature_names,
#      28     class_names=list(iris.target_names)  # make sure this is a list of strings
#      29 )
#      31 # Step 6: Display visualization (in Jupyter)
#      32 viz.show()
#
# ...

# %%
import dtreeviz
import sklearn

print(dtreeviz.__version__)
print(sklearn.__version__)
# Out:
# 2.2.2
# 1.5.1

# %%
pip install --upgrade --pre dtreeviz
# Out:
# ...
#
# ...

# %%
import dtreeviz
print(dtreeviz.__version__)
# Out:
# 2.2.2

# %%
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from dtreeviz import dtreeviz

iris = load_iris()
X, y = iris.data, iris.target

clf = DecisionTreeClassifier(max_depth=3)
clf.fit(X, y)

viz = dtreeviz(
    clf, X, y,
    target_name="species",
    feature_names=iris.feature_names,
    class_names=list(iris.target_names)
)

viz.show()
# Out:
# C:\Users\sumit\AppData\Local\Temp\ipykernel_13152\3703363176.py:11: DeprecationWarning: dtreeviz() function is deprecated starting from version 2.0.
#  For the same functionality, please use this code instead:
#  m = dtreeviz.model(...)
#  m.view()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 11
#       8 clf = DecisionTreeClassifier(max_depth=3)
#       9 clf.fit(X, y)
# ---> 11 viz = dtreeviz(
#      12     clf, X, y,
#      13     target_name="species",
#      14     feature_names=iris.feature_names,
#      15     class_names=list(iris.target_names)
#      16 )
#      18 viz.show()
#
# ...
