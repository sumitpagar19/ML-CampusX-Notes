# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"D:\Downloads\personality_dataset.csv")

# %%
df.head()
# Out:
#    Time_spent_Alone Stage_fear  Social_event_attendance  Going_outside  \
# 0               4.0         No                      4.0            6.0
# 1               9.0        Yes                      0.0            0.0
# 2               9.0        Yes                      1.0            2.0
# 3               0.0         No                      6.0            7.0
# 4               3.0         No                      9.0            4.0
#
#   Drained_after_socializing  Friends_circle_size  Post_frequency Personality
# 0                        No                 13.0             5.0   Extrovert
# 1                       Yes                  0.0             3.0   Introvert
# 2                       Yes                  5.0             2.0   Introvert
# 3                        No                 14.0             8.0   Extrovert
# 4                        No                  8.0             5.0   Extrovert

# %%
df.shape
# Out:
# (2900, 8)

# %%
df.describe()
# Out:
#        Time_spent_Alone  Social_event_attendance  Going_outside  \
# count       2837.000000              2838.000000    2834.000000
# mean           4.505816                 3.963354       3.000000
# std            3.479192                 2.903827       2.247327
# min            0.000000                 0.000000       0.000000
# 25%            2.000000                 2.000000       1.000000
# 50%            4.000000                 3.000000       3.000000
# 75%            8.000000                 6.000000       5.000000
# max           11.000000                10.000000       7.000000
#
#        Friends_circle_size  Post_frequency
# count          2823.000000     2835.000000
# mean              6.268863        3.564727
# std               4.289693        2.926582
# min               0.000000        0.000000
# 25%               3.000000        1.000000
# 50%               5.000000        3.000000
# 75%              10.000000        6.000000
# ...

# %%
plt.hist(['Time_spent_Alone'],bins=4)
# Out:
# (array([0., 0., 1., 0.]),
#  array([-0.5 , -0.25,  0.  ,  0.25,  0.5 ]),
#  <BarContainer object of 4 artists>)

# %%
sns.distplot(df['Time_spent_Alone'])
# Out:
# C:\Users\sumit\AppData\Local\Temp\ipykernel_13904\2930324944.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Time_spent_Alone'])
# <Axes: xlabel='Time_spent_Alone', ylabel='Density'>

# %%
sns.distplot(df['Friends_circle_size'])
# Out:
# C:\Users\sumit\AppData\Local\Temp\ipykernel_13904\696034719.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Friends_circle_size'])
# <Axes: xlabel='Friends_circle_size', ylabel='Density'>

# %%
sns.boxplot(df['Time_spent_Alone'])
# Out:
# <Axes: ylabel='Time_spent_Alone'>

# %%
df['Time_spent_Alone'].mean()
# Out:
# 4.505816002819881

# %%
df['Time_spent_Alone'].max()
# Out:
# 11.0

# %%
df['Time_spent_Alone'].min()
# Out:
# 0.0

# %%
df['Time_spent_Alone'].skew()
# Out:
# 0.38582142719550133

# %%
df['Friends_circle_size'].max()
# Out:
# 15.0

# %%
df['Friends_circle_size'].min()
# Out:
# 0.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2900 entries, 0 to 2899
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Time_spent_Alone           2837 non-null   float64
#  1   Stage_fear                 2827 non-null   object
#  2   Social_event_attendance    2838 non-null   float64
#  3   Going_outside              2834 non-null   float64
#  4   Drained_after_socializing  2848 non-null   object
#  5   Friends_circle_size        2823 non-null   float64
#  6   Post_frequency             2835 non-null   float64
#  7   Personality                2900 non-null   object
# dtypes: float64(5), object(3)
# memory usage: 181.4+ KB
